# %% [markdown]
# <a href="https://colab.research.google.com/github/srirampai/Active_learning/blob/main/active_learning_review_classification_IMDB_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing required libraries

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import re
import string

tfds.disable_progress_bar()

# %% [markdown]
# ## Loading and preprocessing the data
#
# We will be using the IMDB reviews dataset for our experiments. This dataset has 50,000
# reviews in total, including training and testing splits. We will merge these splits and
# sample our own, balanced training, validation and testing sets.

# %%
dataset = tfds.load(
    "imdb_reviews",
    split="train + test",
    as_supervised=True,
    batch_size=-1,
    shuffle_files=False,
)
reviews, labels = tfds.as_numpy(dataset)

print("Total examples:", reviews.shape[0])
# Out:
# Downloading and preparing dataset imdb_reviews/plain_text/1.0.0 (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN44DGA/imdb_reviews-train.tfrecord
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN44DGA/imdb_reviews-test.tfrecord
# Shuffling and writing examples to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0.incompleteN44DGA/imdb_reviews-unsupervised.tfrecord
# WARNING:absl:Dataset is using deprecated text encoder API which will be removed soon. Please use the plain_text version of the dataset and migrate to `tensorflow_text`.
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# Total examples: 50000

# %%
print(type(reviews))
print(type(labels))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# Active learning starts with labeling a subset of data.
# For the ratio sampling technique that we will be using, we will need well-balanced training,
# validation and testing splits.

# %%
#Defining the Split
val_split = 2500
test_split = 2500
train_split = 7500

# Separating the negative and positive samples for manual stratification
x_positives, y_positives = reviews[labels == 1], labels[labels == 1]
x_negatives, y_negatives = reviews[labels == 0], labels[labels == 0]

# Creating training, validation and testing splits
x_val, y_val = (
    tf.concat((x_positives[:val_split], x_negatives[:val_split]), 0),
    tf.concat((y_positives[:val_split], y_negatives[:val_split]), 0),
)
x_test, y_test = (
    tf.concat(
        (
            x_positives[val_split : val_split + test_split],
            x_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split : val_split + test_split],
            y_negatives[val_split : val_split + test_split],
        ),
        0,
    ),
)
x_train, y_train = (
    tf.concat(
        (
            x_positives[val_split + test_split : val_split + test_split + train_split],
            x_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
    tf.concat(
        (
            y_positives[val_split + test_split : val_split + test_split + train_split],
            y_negatives[val_split + test_split : val_split + test_split + train_split],
        ),
        0,
    ),
)

# Remaining pool of samples are stored separately. These are only labeled as and when required
x_pool_positives, y_pool_positives = (
    x_positives[val_split + test_split + train_split :],
    y_positives[val_split + test_split + train_split :],
)
x_pool_negatives, y_pool_negatives = (
    x_negatives[val_split + test_split + train_split :],
    y_negatives[val_split + test_split + train_split :],
)

# Creating TF Datasets for faster prefetching and parallelization
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))

pool_negatives = tf.data.Dataset.from_tensor_slices(
    (x_pool_negatives, y_pool_negatives)
)
pool_positives = tf.data.Dataset.from_tensor_slices(
    (x_pool_positives, y_pool_positives)
)

print(f"Initial training set size: {len(train_dataset)}")
print(f"Validation set size: {len(val_dataset)}")
print(f"Testing set size: {len(test_dataset)}")
print(f"Unlabeled negative pool: {len(pool_negatives)}")
print(f"Unlabeled positive pool: {len(pool_positives)}")
# Out:
# Initial training set size: 15000
# Validation set size: 5000
# Testing set size: 5000
# Unlabeled negative pool: 12500
# Unlabeled positive pool: 12500

# %% [markdown]
# ### Fitting the `TextVectorization` layer
#
# Since we are working with text data, we will need to encode the text strings as vectors which
# would then be passed through an `Embedding` layer. To make this tokenization process
# faster, we use the `map()` function with its parallelization functionality.

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, f"[{re.escape(string.punctuation)}]", ""
    )


vectorizer = layers.TextVectorization(
    3000, standardize=custom_standardization, output_sequence_length=150
)
# Adapting the dataset
vectorizer.adapt(
    train_dataset.map(lambda x, y: x, num_parallel_calls=tf.data.AUTOTUNE).batch(256)
)


def vectorize_text(text, label):
    text = vectorizer(text)
    return text, label


train_dataset = train_dataset.map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
pool_negatives = pool_negatives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)
pool_positives = pool_positives.map(vectorize_text, num_parallel_calls=tf.data.AUTOTUNE)

val_dataset = val_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)
test_dataset = test_dataset.batch(256).map(
    vectorize_text, num_parallel_calls=tf.data.AUTOTUNE
)

# %% [markdown]
# ## Creating Helper Functions

# %%
# Helper function for merging new history objects with older ones
def append_history(losses, val_losses, accuracy, val_accuracy, history):
    losses = losses + history.history["loss"]
    val_losses = val_losses + history.history["val_loss"]
    accuracy = accuracy + history.history["binary_accuracy"]
    val_accuracy = val_accuracy + history.history["val_binary_accuracy"]
    return losses, val_losses, accuracy, val_accuracy


# Plotter function
def plot_history(losses, val_losses, accuracies, val_accuracies):
    plt.plot(losses)
    plt.plot(val_losses)
    plt.legend(["train_loss", "val_loss"])
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.show()

    plt.plot(accuracies)
    plt.plot(val_accuracies)
    plt.legend(["train_accuracy", "val_accuracy"])
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.show()

# %% [markdown]
# ## Creating the Model
#
# We create a small bidirectional LSTM model. When using Active Learning, you should make sure
# that the model architecture is capable of overfitting to the initial data.
# Overfitting gives a strong hint that the model will have enough capacity for
# future, unseen data.

# %%
def create_model():
    model = keras.models.Sequential(
        [
            layers.Input(shape=(150,)),
            layers.Embedding(input_dim=3000, output_dim=128),
            layers.Bidirectional(layers.LSTM(32, return_sequences=True)),
            layers.GlobalMaxPool1D(),
            layers.Dense(20, activation="relu"),
            layers.Dropout(0.5),
            layers.Dense(1, activation="sigmoid"),
        ]
    )
    model.summary()
    return model

# %% [markdown]
# ## Training on the entire dataset
#
# To show the effectiveness of Active Learning, we will first train the model on the entire
# dataset containing 40,000 labeled samples. This model will be used for comparison later.

# %%
#calling the LSTM models created
def train_full_model(full_train_dataset, val_dataset, test_dataset):
    model = create_model()
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
        ],
    )

    # We will save the best model at every epoch and load the best one for evaluation on the test set
    history = model.fit(
        full_train_dataset.batch(256),
        epochs=20,
        validation_data=val_dataset,
        callbacks=[
            keras.callbacks.EarlyStopping(patience=10, verbose=1),
            keras.callbacks.ModelCheckpoint(
                "FullModelCheckpoint.h5", verbose=1, save_best_only=True
            ),
        ],
    )

    # Plot history
    plot_history(
        history.history["loss"],
        history.history["val_loss"],
        history.history["binary_accuracy"],
        history.history["val_binary_accuracy"],
    )

    # Loading the best checkpoint
    model = keras.models.load_model("FullModelCheckpoint.h5")

    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)
    return model


# Sampling the full train dataset to train on
full_train_dataset = (
    train_dataset.concatenate(pool_positives)
    .concatenate(pool_negatives)
    .cache()
    .shuffle(20000)
)

# Training the full model
full_dataset_model = train_full_model(full_train_dataset, val_dataset, test_dataset)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 150, 128)          384000
#
#  bidirectional_1 (Bidirectio  (None, 150, 64)          41216
#  nal)
#
#  global_max_pooling1d_1 (Glo  (None, 64)               0
#  balMaxPooling1D)
#
#  dense_2 (Dense)             (None, 20)                1300
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 157/157 [==============================] - ETA: 0s - loss: 0.5021 - binary_accuracy: 0.7655 - false_negatives_1: 2987.0000 - false_positives_1: 6392.0000
# Epoch 00001: val_loss improved from inf to 0.47902, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 29s 110ms/step - loss: 0.5021 - binary_accuracy: 0.7655 - false_negatives_1: 2987.0000 - false_positives_1: 6392.0000 - val_loss: 0.4790 - val_binary_accuracy: 0.7666 - val_false_negatives_1: 1095.0000 - val_false_positives_1: 72.0000
# Epoch 2/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.3619 - binary_accuracy: 0.8532 - false_negatives_1: 2924.0000 - false_positives_1: 2938.0000
# Epoch 00002: val_loss improved from 0.47902 to 0.33233, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 0.3620 - binary_accuracy: 0.8532 - false_negatives_1: 2931.0000 - false_positives_1: 2942.0000 - val_loss: 0.3323 - val_binary_accuracy: 0.8572 - val_false_negatives_1: 291.0000 - val_false_positives_1: 423.0000
# Epoch 3/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.3256 - binary_accuracy: 0.8712 - false_negatives_1: 2495.0000 - false_positives_1: 2649.0000
# Epoch 00003: val_loss did not improve from 0.33233
# 157/157 [==============================] - 10s 66ms/step - loss: 0.3256 - binary_accuracy: 0.8712 - false_negatives_1: 2501.0000 - false_positives_1: 2652.0000 - val_loss: 0.3329 - val_binary_accuracy: 0.8518 - val_false_negatives_1: 455.0000 - val_false_positives_1: 286.0000
# Epoch 4/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.3114 - binary_accuracy: 0.8785 - false_negatives_1: 2359.0000 - false_positives_1: 2493.0000
# Epoch 00004: val_loss improved from 0.33233 to 0.32848, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 11s 70ms/step - loss: 0.3116 - binary_accuracy: 0.8785 - false_negatives_1: 2365.0000 - false_positives_1: 2495.0000 - val_loss: 0.3285 - val_binary_accuracy: 0.8594 - val_false_negatives_1: 275.0000 - val_false_positives_1: 428.0000
# Epoch 5/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2890 - binary_accuracy: 0.8893 - false_negatives_1: 2117.0000 - false_positives_1: 2304.0000
# Epoch 00005: val_loss improved from 0.32848 to 0.32064, saving model to FullModelCheckpoint.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 0.2893 - binary_accuracy: 0.8892 - false_negatives_1: 2122.0000 - false_positives_1: 2309.0000 - val_loss: 0.3206 - val_binary_accuracy: 0.8632 - val_false_negatives_1: 310.0000 - val_false_positives_1: 374.0000
# Epoch 6/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2784 - binary_accuracy: 0.8935 - false_negatives_1: 1991.0000 - false_positives_1: 2262.0000
# Epoch 00006: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 60ms/step - loss: 0.2783 - binary_accuracy: 0.8935 - false_negatives_1: 1997.0000 - false_positives_1: 2263.0000 - val_loss: 0.3640 - val_binary_accuracy: 0.8490 - val_false_negatives_1: 545.0000 - val_false_positives_1: 210.0000
# Epoch 7/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2642 - binary_accuracy: 0.9012 - false_negatives_1: 1879.0000 - false_positives_1: 2068.0000
# Epoch 00007: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 59ms/step - loss: 0.2641 - binary_accuracy: 0.9013 - false_negatives_1: 1880.0000 - false_positives_1: 2070.0000 - val_loss: 0.3427 - val_binary_accuracy: 0.8606 - val_false_negatives_1: 353.0000 - val_false_positives_1: 344.0000
# Epoch 8/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2487 - binary_accuracy: 0.9061 - false_negatives_1: 1762.0000 - false_positives_1: 1986.0000
# Epoch 00008: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 59ms/step - loss: 0.2488 - binary_accuracy: 0.9061 - false_negatives_1: 1764.0000 - false_positives_1: 1991.0000 - val_loss: 0.3334 - val_binary_accuracy: 0.8570 - val_false_negatives_1: 403.0000 - val_false_positives_1: 312.0000
# Epoch 9/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2342 - binary_accuracy: 0.9133 - false_negatives_1: 1666.0000 - false_positives_1: 1797.0000
# Epoch 00009: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2341 - binary_accuracy: 0.9133 - false_negatives_1: 1669.0000 - false_positives_1: 1797.0000 - val_loss: 0.3673 - val_binary_accuracy: 0.8496 - val_false_negatives_1: 492.0000 - val_false_positives_1: 260.0000
# Epoch 10/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2224 - binary_accuracy: 0.9197 - false_negatives_1: 1526.0000 - false_positives_1: 1679.0000
# Epoch 00010: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2223 - binary_accuracy: 0.9197 - false_negatives_1: 1529.0000 - false_positives_1: 1682.0000 - val_loss: 0.3556 - val_binary_accuracy: 0.8584 - val_false_negatives_1: 342.0000 - val_false_positives_1: 366.0000
# Epoch 11/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.2061 - binary_accuracy: 0.9249 - false_negatives_1: 1384.0000 - false_positives_1: 1616.0000
# Epoch 00011: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2061 - binary_accuracy: 0.9249 - false_negatives_1: 1385.0000 - false_positives_1: 1620.0000 - val_loss: 0.4729 - val_binary_accuracy: 0.8236 - val_false_negatives_1: 714.0000 - val_false_positives_1: 168.0000
# Epoch 12/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.1920 - binary_accuracy: 0.9312 - false_negatives_1: 1287.0000 - false_positives_1: 1462.0000
# Epoch 00012: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1919 - binary_accuracy: 0.9312 - false_negatives_1: 1288.0000 - false_positives_1: 1465.0000 - val_loss: 0.5042 - val_binary_accuracy: 0.8262 - val_false_negatives_1: 685.0000 - val_false_positives_1: 184.0000
# Epoch 13/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.1783 - binary_accuracy: 0.9373 - false_negatives_1: 1174.0000 - false_positives_1: 1328.0000
# Epoch 00013: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1783 - binary_accuracy: 0.9373 - false_negatives_1: 1175.0000 - false_positives_1: 1331.0000 - val_loss: 0.4535 - val_binary_accuracy: 0.8466 - val_false_negatives_1: 248.0000 - val_false_positives_1: 519.0000
# Epoch 14/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.1621 - binary_accuracy: 0.9445 - false_negatives_1: 1070.0000 - false_positives_1: 1146.0000
# Epoch 00014: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1622 - binary_accuracy: 0.9445 - false_negatives_1: 1073.0000 - false_positives_1: 1147.0000 - val_loss: 0.4110 - val_binary_accuracy: 0.8516 - val_false_negatives_1: 397.0000 - val_false_positives_1: 345.0000
# Epoch 15/20
# 156/157 [============================>.] - ETA: 0s - loss: 0.1504 - binary_accuracy: 0.9495 - false_negatives_1: 948.0000 - false_positives_1: 1070.0000
# Epoch 00015: val_loss did not improve from 0.32064
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1504 - binary_accuracy: 0.9494 - false_negatives_1: 950.0000 - false_positives_1: 1073.0000 - val_loss: 0.4813 - val_binary_accuracy: 0.8520 - val_false_negatives_1: 396.0000 - val_false_positives_1: 344.0000
# Epoch 00015: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3284772038459778, 'binary_accuracy': 0.8626000285148621, 'false_negatives_1': 334.0, 'false_positives_1': 353.0}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Training via Active Learning
#
# The general process we follow when performing Active Learning is demonstrated below:
#
# ![Active Learning](https://i.imgur.com/dmNKusp.png)
#
# The pipeline can be summarized in five parts:
#
# 1. Sample and annotate a small, balanced training dataset
# 2. Train the model on this small subset
# 3. Evaluate the model on a balanced testing set
# 4. If the model satisfies the business criteria, deploy it in a real time setting
# 5. If it doesn't pass the criteria, sample a few more samples according to the ratio of
# false positives and negatives, add them to the training set and repeat from step 2 till
# the model passes the tests or till all available data is exhausted.
#
# For the code below, we will perform sampling using the following formula:<br/>
#
# ![Ratio Sampling](https://i.imgur.com/LyZEiZL.png)
#
# Active Learning techniques use callbacks extensively for progress tracking. We will be
# using model checkpointing and early stopping for this example. The `patience` parameter
# for Early Stopping can help minimize overfitting and the time required. We have set it
# `patience=4` for now but since the model is robust, we can increase the patience level if
# desired.
#
# Note: We are not loading the checkpoint after the first training iteration. In my
# experience working on Active Learning techniques, this helps the model probe the
# newly formed loss landscape. Even if the model fails to improve in the second iteration,
# we will still gain insight about the possible future false positive and negative rates.
# This will help us sample a better set in the next iteration where the model will have a
# greater chance to improve.

# %%
def train_active_learning_models(
    train_dataset,
    pool_negatives,
    pool_positives,
    val_dataset,
    test_dataset,
    num_iterations=3,
    sampling_size=5000,
):

    # Creating lists for storing metrics
    losses, val_losses, accuracies, val_accuracies = [], [], [], []

    model = create_model()
    # We will monitor the false positives and false negatives predicted by our model
    # These will decide the subsequent sampling ratio for every Active Learning loop
    model.compile(
        loss="binary_crossentropy",
        optimizer="rmsprop",
        metrics=[
            keras.metrics.BinaryAccuracy(),
            keras.metrics.FalseNegatives(),
            keras.metrics.FalsePositives(),
            keras.metrics.Precision(),
            keras.metrics.Recall(),
            keras.metrics.TruePositives(),
            keras.metrics.TrueNegatives(),
            keras.metrics.AUC()
        ],
    )

    # Defining checkpoints.
    # The checkpoint callback is reused throughout the training since it only saves the best overall model.
    checkpoint = keras.callbacks.ModelCheckpoint(
        "AL_Model.h5", save_best_only=True, verbose=1
    )
    # Here, patience is set to 10. This can be set higher if desired.
    early_stopping = keras.callbacks.EarlyStopping(patience=10, verbose=1)

    print(f"Starting to train with {len(train_dataset)} samples")
    # Initial fit with a small subset of the training set
    history = model.fit(
        train_dataset.cache().shuffle(20000).batch(256),
        epochs=15,
        validation_data=val_dataset,
        callbacks=[checkpoint, early_stopping],
    )

    # Appending history
    losses, val_losses, accuracies, val_accuracies = append_history(
        losses, val_losses, accuracies, val_accuracies, history
    )

    for iteration in range(num_iterations):
        # Getting predictions from previously trained model
        predictions = model.predict(test_dataset)

        # Generating labels from the output probabilities
        rounded = tf.where(tf.greater(predictions, 0.5), 1, 0)

        # Evaluating the number of zeros and ones incorrrectly classified
        _, _, false_negatives, false_positives, precision, recall, true_postives, true_negatives, auc= model.evaluate(test_dataset, verbose=0)

        print("-" * 100)
        print(
            f"Number of zeros incorrectly classified: {false_negatives}, Number of ones incorrectly classified: {false_positives}"
        )

        # This technique of Active Learning demonstrates ratio based sampling where
        # Number of ones/zeros to sample = Number of ones/zeros incorrectly classified / Total incorrectly classified
        if false_negatives != 0 and false_positives != 0:
            total = false_negatives + false_positives
            sample_ratio_ones, sample_ratio_zeros = (
                false_positives / total,
                false_negatives / total,
            )
        # In the case where all samples are correctly predicted, we can sample both classes equally
        else:
            sample_ratio_ones, sample_ratio_zeros = 0.5, 0.5

        print(
            f"Sample ratio for positives: {sample_ratio_ones}, Sample ratio for negatives:{sample_ratio_zeros}"
        )

        # Sample the required number of ones and zeros
        sampled_dataset = pool_negatives.take(
            int(sample_ratio_zeros * sampling_size)
        ).concatenate(pool_positives.take(int(sample_ratio_ones * sampling_size)))

        # Skip the sampled data points to avoid repetition of sample
        pool_negatives = pool_negatives.skip(int(sample_ratio_zeros * sampling_size))
        pool_positives = pool_positives.skip(int(sample_ratio_ones * sampling_size))

        # Concatenating the train_dataset with the sampled_dataset
        train_dataset = train_dataset.concatenate(sampled_dataset).prefetch(
            tf.data.AUTOTUNE
        )

        print(f"Starting training with {len(train_dataset)} samples")
        print("-" * 100)

        # We recompile the model to reset the optimizer states and retrain the model
        model.compile(
            loss="binary_crossentropy",
            optimizer="rmsprop",
            metrics=[
                keras.metrics.BinaryAccuracy(),
                keras.metrics.FalseNegatives(),
                keras.metrics.FalsePositives(),
                keras.metrics.Precision(),
                keras.metrics.Recall(),
                keras.metrics.TruePositives(),
                keras.metrics.TrueNegatives(),
                keras.metrics.AUC()
            ],
        )
        history = model.fit(
            train_dataset.cache().shuffle(20000).batch(256),
            validation_data=val_dataset,
            epochs=20,
            callbacks=[
                checkpoint,
                keras.callbacks.EarlyStopping(patience=10, verbose=1),
            ],
        )

        # Appending the history
        losses, val_losses, accuracies, val_accuracies = append_history(
            losses, val_losses, accuracies, val_accuracies, history
        )

        # Loading the best model from this training loop
        model = keras.models.load_model("AL_Model.h5")

    # Plotting the overall history and evaluating the final model
    plot_history(losses, val_losses, accuracies, val_accuracies)
    print("-" * 100)
    print(
        "Test set evaluation: ",
        model.evaluate(test_dataset, verbose=0, return_dict=True),
    )
    print("-" * 100)

    return model


active_learning_model = train_active_learning_models(
    train_dataset, pool_negatives, pool_positives, val_dataset, test_dataset
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 150, 128)          384000
#
#  bidirectional (Bidirectiona  (None, 150, 64)          41216
#  l)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 20)                1300
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 426,537
# Trainable params: 426,537
# Non-trainable params: 0
# _________________________________________________________________
# Starting to train with 15000 samples
# Epoch 1/15
# 59/59 [==============================] - ETA: 0s - loss: 0.6327 - binary_accuracy: 0.6546 - false_negatives: 2487.0000 - false_positives: 2694.0000 - precision: 0.6504 - recall: 0.6684 - true_positives: 5013.0000 - true_negatives: 4806.0000 - auc: 0.7125
# Epoch 00001: val_loss improved from inf to 0.48213, saving model to AL_Model.h5
# 59/59 [==============================] - 19s 119ms/step - loss: 0.6327 - binary_accuracy: 0.6546 - false_negatives: 2487.0000 - false_positives: 2694.0000 - precision: 0.6504 - recall: 0.6684 - true_positives: 5013.0000 - true_negatives: 4806.0000 - auc: 0.7125 - val_loss: 0.4821 - val_binary_accuracy: 0.7972 - val_false_negatives: 778.0000 - val_false_positives: 236.0000 - val_precision: 0.8795 - val_recall: 0.6888 - val_true_positives: 1722.0000 - val_true_negatives: 2264.0000 - val_auc: 0.8948
# Epoch 2/15
# 59/59 [==============================] - ETA: 0s - loss: 0.4538 - binary_accuracy: 0.8165 - false_negatives: 1357.0000 - false_positives: 1395.0000 - precision: 0.8149 - recall: 0.8191 - true_positives: 6143.0000 - true_negatives: 6105.0000 - auc: 0.8753
# Epoch 00002: val_loss improved from 0.48213 to 0.37935, saving model to AL_Model.h5
# 59/59 [==============================] - 5s 90ms/step - loss: 0.4538 - binary_accuracy: 0.8165 - false_negatives: 1357.0000 - false_positives: 1395.0000 - precision: 0.8149 - recall: 0.8191 - true_positives: 6143.0000 - true_negatives: 6105.0000 - auc: 0.8753 - val_loss: 0.3793 - val_binary_accuracy: 0.8344 - val_false_negatives: 430.0000 - val_false_positives: 398.0000 - val_precision: 0.8387 - val_recall: 0.8280 - val_true_positives: 2070.0000 - val_true_negatives: 2102.0000 - val_auc: 0.9157
# Epoch 3/15
# 59/59 [==============================] - ETA: 0s - loss: 0.3833 - binary_accuracy: 0.8455 - false_negatives: 1095.0000 - false_positives: 1223.0000 - precision: 0.8397 - recall: 0.8540 - true_positives: 6405.0000 - true_negatives: 6277.0000 - auc: 0.9115
# Epoch 00003: val_loss improved from 0.37935 to 0.35852, saving model to AL_Model.h5
# 59/59 [==============================] - 5s 91ms/step - loss: 0.3833 - binary_accuracy: 0.8455 - false_negatives: 1095.0000 - false_positives: 1223.0000 - precision: 0.8397 - recall: 0.8540 - true_positives: 6405.0000 - true_negatives: 6277.0000 - auc: 0.9115 - val_loss: 0.3585 - val_binary_accuracy: 0.8418 - val_false_negatives: 429.0000 - val_false_positives: 362.0000 - val_precision: 0.8512 - val_recall: 0.8284 - val_true_positives: 2071.0000 - val_true_negatives: 2138.0000 - val_auc: 0.9227
# Epoch 4/15
# 59/59 [==============================] - ETA: 0s - loss: 0.3382 - binary_accuracy: 0.8651 - false_negatives: 958.0000 - false_positives: 1066.0000 - precision: 0.8599 - recall: 0.8723 - true_positives: 6542.0000 - true_negatives: 6434.0000 - auc: 0.9310
# Epoch 00004: val_loss did not improve from 0.35852
# 59/59 [==============================] - 5s 89ms/step - loss: 0.3382 - binary_accuracy: 0.8651 - false_negatives: 958.0000 - false_positives: 1066.0000 - precision: 0.8599 - recall: 0.8723 - true_positives: 6542.0000 - true_negatives: 6434.0000 - auc: 0.9310 - val_loss: 0.3932 - val_binary_accuracy: 0.8314 - val_false_negatives: 166.0000 - val_false_positives: 677.0000 - val_precision: 0.7752 - val_recall: 0.9336 - val_true_positives: 2334.0000 - val_true_negatives: 1823.0000 - val_auc: 0.9250
# Epoch 5/15
# 59/59 [==============================] - ETA: 0s - loss: 0.3126 - binary_accuracy: 0.8783 - false_negatives: 844.0000 - false_positives: 981.0000 - precision: 0.8715 - recall: 0.8875 - true_positives: 6656.0000 - true_negatives: 6519.0000 - auc: 0.9409
# Epoch 00005: val_loss improved from 0.35852 to 0.34901, saving model to AL_Model.h5
# 59/59 [==============================] - 5s 90ms/step - loss: 0.3126 - binary_accuracy: 0.8783 - false_negatives: 844.0000 - false_positives: 981.0000 - precision: 0.8715 - recall: 0.8875 - true_positives: 6656.0000 - true_negatives: 6519.0000 - auc: 0.9409 - val_loss: 0.3490 - val_binary_accuracy: 0.8442 - val_false_negatives: 431.0000 - val_false_positives: 348.0000 - val_precision: 0.8560 - val_recall: 0.8276 - val_true_positives: 2069.0000 - val_true_negatives: 2152.0000 - val_auc: 0.9260
# Epoch 6/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2857 - binary_accuracy: 0.8930 - false_negatives: 770.0000 - false_positives: 835.0000 - precision: 0.8896 - recall: 0.8973 - true_positives: 6730.0000 - true_negatives: 6665.0000 - auc: 0.9508
# Epoch 00006: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 88ms/step - loss: 0.2857 - binary_accuracy: 0.8930 - false_negatives: 770.0000 - false_positives: 835.0000 - precision: 0.8896 - recall: 0.8973 - true_positives: 6730.0000 - true_negatives: 6665.0000 - auc: 0.9508 - val_loss: 0.5141 - val_binary_accuracy: 0.8060 - val_false_negatives: 111.0000 - val_false_positives: 859.0000 - val_precision: 0.7355 - val_recall: 0.9556 - val_true_positives: 2389.0000 - val_true_negatives: 1641.0000 - val_auc: 0.9226
# Epoch 7/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2707 - binary_accuracy: 0.8973 - false_negatives: 732.0000 - false_positives: 808.0000 - precision: 0.8933 - recall: 0.9024 - true_positives: 6768.0000 - true_negatives: 6692.0000 - auc: 0.9556
# Epoch 00007: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 85ms/step - loss: 0.2707 - binary_accuracy: 0.8973 - false_negatives: 732.0000 - false_positives: 808.0000 - precision: 0.8933 - recall: 0.9024 - true_positives: 6768.0000 - true_negatives: 6692.0000 - auc: 0.9556 - val_loss: 0.3762 - val_binary_accuracy: 0.8428 - val_false_negatives: 447.0000 - val_false_positives: 339.0000 - val_precision: 0.8583 - val_recall: 0.8212 - val_true_positives: 2053.0000 - val_true_negatives: 2161.0000 - val_auc: 0.9232
# Epoch 8/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2460 - binary_accuracy: 0.9115 - false_negatives: 649.0000 - false_positives: 679.0000 - precision: 0.9098 - recall: 0.9135 - true_positives: 6851.0000 - true_negatives: 6821.0000 - auc: 0.9631
# Epoch 00008: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 82ms/step - loss: 0.2460 - binary_accuracy: 0.9115 - false_negatives: 649.0000 - false_positives: 679.0000 - precision: 0.9098 - recall: 0.9135 - true_positives: 6851.0000 - true_negatives: 6821.0000 - auc: 0.9631 - val_loss: 0.4839 - val_binary_accuracy: 0.8104 - val_false_negatives: 127.0000 - val_false_positives: 821.0000 - val_precision: 0.7430 - val_recall: 0.9492 - val_true_positives: 2373.0000 - val_true_negatives: 1679.0000 - val_auc: 0.9192
# Epoch 9/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2312 - binary_accuracy: 0.9153 - false_negatives: 595.0000 - false_positives: 675.0000 - precision: 0.9109 - recall: 0.9207 - true_positives: 6905.0000 - true_negatives: 6825.0000 - auc: 0.9675
# Epoch 00009: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 82ms/step - loss: 0.2312 - binary_accuracy: 0.9153 - false_negatives: 595.0000 - false_positives: 675.0000 - precision: 0.9109 - recall: 0.9207 - true_positives: 6905.0000 - true_negatives: 6825.0000 - auc: 0.9675 - val_loss: 0.4433 - val_binary_accuracy: 0.8292 - val_false_negatives: 556.0000 - val_false_positives: 298.0000 - val_precision: 0.8671 - val_recall: 0.7776 - val_true_positives: 1944.0000 - val_true_negatives: 2202.0000 - val_auc: 0.9179
# Epoch 10/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2122 - binary_accuracy: 0.9243 - false_negatives: 573.0000 - false_positives: 563.0000 - precision: 0.9248 - recall: 0.9236 - true_positives: 6927.0000 - true_negatives: 6937.0000 - auc: 0.9722
# Epoch 00010: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 82ms/step - loss: 0.2122 - binary_accuracy: 0.9243 - false_negatives: 573.0000 - false_positives: 563.0000 - precision: 0.9248 - recall: 0.9236 - true_positives: 6927.0000 - true_negatives: 6937.0000 - auc: 0.9722 - val_loss: 0.4489 - val_binary_accuracy: 0.8352 - val_false_negatives: 248.0000 - val_false_positives: 576.0000 - val_precision: 0.7963 - val_recall: 0.9008 - val_true_positives: 2252.0000 - val_true_negatives: 1924.0000 - val_auc: 0.9184
# Epoch 11/15
# 59/59 [==============================] - ETA: 0s - loss: 0.2010 - binary_accuracy: 0.9301 - false_negatives: 518.0000 - false_positives: 531.0000 - precision: 0.9293 - recall: 0.9309 - true_positives: 6982.0000 - true_negatives: 6969.0000 - auc: 0.9754
# Epoch 00011: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 82ms/step - loss: 0.2010 - binary_accuracy: 0.9301 - false_negatives: 518.0000 - false_positives: 531.0000 - precision: 0.9293 - recall: 0.9309 - true_positives: 6982.0000 - true_negatives: 6969.0000 - auc: 0.9754 - val_loss: 0.4930 - val_binary_accuracy: 0.8166 - val_false_negatives: 689.0000 - val_false_positives: 228.0000 - val_precision: 0.8882 - val_recall: 0.7244 - val_true_positives: 1811.0000 - val_true_negatives: 2272.0000 - val_auc: 0.9125
# Epoch 12/15
# 59/59 [==============================] - ETA: 0s - loss: 0.1844 - binary_accuracy: 0.9372 - false_negatives: 485.0000 - false_positives: 457.0000 - precision: 0.9388 - recall: 0.9353 - true_positives: 7015.0000 - true_negatives: 7043.0000 - auc: 0.9788
# Epoch 00012: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 82ms/step - loss: 0.1844 - binary_accuracy: 0.9372 - false_negatives: 485.0000 - false_positives: 457.0000 - precision: 0.9388 - recall: 0.9353 - true_positives: 7015.0000 - true_negatives: 7043.0000 - auc: 0.9788 - val_loss: 0.4796 - val_binary_accuracy: 0.8314 - val_false_negatives: 523.0000 - val_false_positives: 320.0000 - val_precision: 0.8607 - val_recall: 0.7908 - val_true_positives: 1977.0000 - val_true_negatives: 2180.0000 - val_auc: 0.9124
# Epoch 13/15
# 59/59 [==============================] - ETA: 0s - loss: 0.1760 - binary_accuracy: 0.9407 - false_negatives: 464.0000 - false_positives: 426.0000 - precision: 0.9429 - recall: 0.9381 - true_positives: 7036.0000 - true_negatives: 7074.0000 - auc: 0.9803
# Epoch 00013: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 81ms/step - loss: 0.1760 - binary_accuracy: 0.9407 - false_negatives: 464.0000 - false_positives: 426.0000 - precision: 0.9429 - recall: 0.9381 - true_positives: 7036.0000 - true_negatives: 7074.0000 - auc: 0.9803 - val_loss: 0.5045 - val_binary_accuracy: 0.8302 - val_false_negatives: 287.0000 - val_false_positives: 562.0000 - val_precision: 0.7975 - val_recall: 0.8852 - val_true_positives: 2213.0000 - val_true_negatives: 1938.0000 - val_auc: 0.9092
# Epoch 14/15
# 59/59 [==============================] - ETA: 0s - loss: 0.1559 - binary_accuracy: 0.9473 - false_negatives: 388.0000 - false_positives: 403.0000 - precision: 0.9464 - recall: 0.9483 - true_positives: 7112.0000 - true_negatives: 7097.0000 - auc: 0.9842
# Epoch 00014: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 80ms/step - loss: 0.1559 - binary_accuracy: 0.9473 - false_negatives: 388.0000 - false_positives: 403.0000 - precision: 0.9464 - recall: 0.9483 - true_positives: 7112.0000 - true_negatives: 7097.0000 - auc: 0.9842 - val_loss: 0.5279 - val_binary_accuracy: 0.8330 - val_false_negatives: 456.0000 - val_false_positives: 379.0000 - val_precision: 0.8436 - val_recall: 0.8176 - val_true_positives: 2044.0000 - val_true_negatives: 2121.0000 - val_auc: 0.9081
# Epoch 15/15
# 59/59 [==============================] - ETA: 0s - loss: 0.1429 - binary_accuracy: 0.9545 - false_negatives: 364.0000 - false_positives: 319.0000 - precision: 0.9572 - recall: 0.9515 - true_positives: 7136.0000 - true_negatives: 7181.0000 - auc: 0.9865
# Epoch 00015: val_loss did not improve from 0.34901
# 59/59 [==============================] - 5s 81ms/step - loss: 0.1429 - binary_accuracy: 0.9545 - false_negatives: 364.0000 - false_positives: 319.0000 - precision: 0.9572 - recall: 0.9515 - true_positives: 7136.0000 - true_negatives: 7181.0000 - auc: 0.9865 - val_loss: 0.5584 - val_binary_accuracy: 0.8312 - val_false_negatives: 341.0000 - val_false_positives: 503.0000 - val_precision: 0.8110 - val_recall: 0.8636 - val_true_positives: 2159.0000 - val_true_negatives: 1997.0000 - val_auc: 0.9047
# Epoch 00015: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 390.0, Number of ones incorrectly classified: 461.0
# Sample ratio for positives: 0.5417156286721504, Sample ratio for negatives:0.4582843713278496
# Starting training with 19999 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2469 - binary_accuracy: 0.9195 - false_negatives_1: 857.0000 - false_positives_1: 753.0000 - precision_1: 0.9255 - recall_1: 0.9160 - true_positives_1: 9351.0000 - true_negatives_1: 9038.0000 - auc_1: 0.9628
# Epoch 00001: val_loss did not improve from 0.34901
# 79/79 [==============================] - 17s 108ms/step - loss: 0.2469 - binary_accuracy: 0.9195 - false_negatives_1: 857.0000 - false_positives_1: 753.0000 - precision_1: 0.9255 - recall_1: 0.9160 - true_positives_1: 9351.0000 - true_negatives_1: 9038.0000 - auc_1: 0.9628 - val_loss: 0.4643 - val_binary_accuracy: 0.8116 - val_false_negatives_1: 726.0000 - val_false_positives_1: 216.0000 - val_precision_1: 0.8915 - val_recall_1: 0.7096 - val_true_positives_1: 1774.0000 - val_true_negatives_1: 2284.0000 - val_auc_1: 0.9157
# Epoch 2/20
# 79/79 [==============================] - ETA: 0s - loss: 0.2062 - binary_accuracy: 0.9321 - false_negatives_1: 707.0000 - false_positives_1: 650.0000 - precision_1: 0.9360 - recall_1: 0.9307 - true_positives_1: 9501.0000 - true_negatives_1: 9141.0000 - auc_1: 0.9732
# Epoch 00002: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 88ms/step - loss: 0.2062 - binary_accuracy: 0.9321 - false_negatives_1: 707.0000 - false_positives_1: 650.0000 - precision_1: 0.9360 - recall_1: 0.9307 - true_positives_1: 9501.0000 - true_negatives_1: 9141.0000 - auc_1: 0.9732 - val_loss: 0.4526 - val_binary_accuracy: 0.8354 - val_false_negatives_1: 353.0000 - val_false_positives_1: 470.0000 - val_precision_1: 0.8204 - val_recall_1: 0.8588 - val_true_positives_1: 2147.0000 - val_true_negatives_1: 2030.0000 - val_auc_1: 0.9151
# Epoch 3/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1903 - binary_accuracy: 0.9379 - false_negatives_1: 641.0000 - false_positives_1: 600.0000 - precision_1: 0.9410 - recall_1: 0.9372 - true_positives_1: 9567.0000 - true_negatives_1: 9191.0000 - auc_1: 0.9767
# Epoch 00003: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 86ms/step - loss: 0.1903 - binary_accuracy: 0.9379 - false_negatives_1: 641.0000 - false_positives_1: 600.0000 - precision_1: 0.9410 - recall_1: 0.9372 - true_positives_1: 9567.0000 - true_negatives_1: 9191.0000 - auc_1: 0.9767 - val_loss: 0.4583 - val_binary_accuracy: 0.8332 - val_false_negatives_1: 355.0000 - val_false_positives_1: 479.0000 - val_precision_1: 0.8175 - val_recall_1: 0.8580 - val_true_positives_1: 2145.0000 - val_true_negatives_1: 2021.0000 - val_auc_1: 0.9153
# Epoch 4/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1691 - binary_accuracy: 0.9461 - false_negatives_1: 550.0000 - false_positives_1: 527.0000 - precision_1: 0.9483 - recall_1: 0.9461 - true_positives_1: 9658.0000 - true_negatives_1: 9264.0000 - auc_1: 0.9813
# Epoch 00004: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 84ms/step - loss: 0.1691 - binary_accuracy: 0.9461 - false_negatives_1: 550.0000 - false_positives_1: 527.0000 - precision_1: 0.9483 - recall_1: 0.9461 - true_positives_1: 9658.0000 - true_negatives_1: 9264.0000 - auc_1: 0.9813 - val_loss: 0.4713 - val_binary_accuracy: 0.8324 - val_false_negatives_1: 461.0000 - val_false_positives_1: 377.0000 - val_precision_1: 0.8440 - val_recall_1: 0.8156 - val_true_positives_1: 2039.0000 - val_true_negatives_1: 2123.0000 - val_auc_1: 0.9130
# Epoch 5/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1545 - binary_accuracy: 0.9508 - false_negatives_1: 506.0000 - false_positives_1: 477.0000 - precision_1: 0.9531 - recall_1: 0.9504 - true_positives_1: 9702.0000 - true_negatives_1: 9314.0000 - auc_1: 0.9842
# Epoch 00005: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 88ms/step - loss: 0.1545 - binary_accuracy: 0.9508 - false_negatives_1: 506.0000 - false_positives_1: 477.0000 - precision_1: 0.9531 - recall_1: 0.9504 - true_positives_1: 9702.0000 - true_negatives_1: 9314.0000 - auc_1: 0.9842 - val_loss: 0.5075 - val_binary_accuracy: 0.8322 - val_false_negatives_1: 375.0000 - val_false_positives_1: 464.0000 - val_precision_1: 0.8208 - val_recall_1: 0.8500 - val_true_positives_1: 2125.0000 - val_true_negatives_1: 2036.0000 - val_auc_1: 0.9098
# Epoch 6/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1382 - binary_accuracy: 0.9562 - false_negatives_1: 452.0000 - false_positives_1: 423.0000 - precision_1: 0.9584 - recall_1: 0.9557 - true_positives_1: 9756.0000 - true_negatives_1: 9368.0000 - auc_1: 0.9871
# Epoch 00006: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 86ms/step - loss: 0.1382 - binary_accuracy: 0.9562 - false_negatives_1: 452.0000 - false_positives_1: 423.0000 - precision_1: 0.9584 - recall_1: 0.9557 - true_positives_1: 9756.0000 - true_negatives_1: 9368.0000 - auc_1: 0.9871 - val_loss: 0.6570 - val_binary_accuracy: 0.8234 - val_false_negatives_1: 261.0000 - val_false_positives_1: 622.0000 - val_precision_1: 0.7826 - val_recall_1: 0.8956 - val_true_positives_1: 2239.0000 - val_true_negatives_1: 1878.0000 - val_auc_1: 0.9001
# Epoch 7/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1265 - binary_accuracy: 0.9622 - false_negatives_1: 384.0000 - false_positives_1: 372.0000 - precision_1: 0.9635 - recall_1: 0.9624 - true_positives_1: 9824.0000 - true_negatives_1: 9419.0000 - auc_1: 0.9885
# Epoch 00007: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 85ms/step - loss: 0.1265 - binary_accuracy: 0.9622 - false_negatives_1: 384.0000 - false_positives_1: 372.0000 - precision_1: 0.9635 - recall_1: 0.9624 - true_positives_1: 9824.0000 - true_negatives_1: 9419.0000 - auc_1: 0.9885 - val_loss: 0.6230 - val_binary_accuracy: 0.8260 - val_false_negatives_1: 344.0000 - val_false_positives_1: 526.0000 - val_precision_1: 0.8039 - val_recall_1: 0.8624 - val_true_positives_1: 2156.0000 - val_true_negatives_1: 1974.0000 - val_auc_1: 0.9004
# Epoch 8/20
# 79/79 [==============================] - ETA: 0s - loss: 0.1127 - binary_accuracy: 0.9638 - false_negatives_1: 376.0000 - false_positives_1: 348.0000 - precision_1: 0.9658 - recall_1: 0.9632 - true_positives_1: 9832.0000 - true_negatives_1: 9443.0000 - auc_1: 0.9909
# Epoch 00008: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 85ms/step - loss: 0.1127 - binary_accuracy: 0.9638 - false_negatives_1: 376.0000 - false_positives_1: 348.0000 - precision_1: 0.9658 - recall_1: 0.9632 - true_positives_1: 9832.0000 - true_negatives_1: 9443.0000 - auc_1: 0.9909 - val_loss: 0.9222 - val_binary_accuracy: 0.7608 - val_false_negatives_1: 1011.0000 - val_false_positives_1: 185.0000 - val_precision_1: 0.8895 - val_recall_1: 0.5956 - val_true_positives_1: 1489.0000 - val_true_negatives_1: 2315.0000 - val_auc_1: 0.8775
# Epoch 9/20
# 79/79 [==============================] - ETA: 0s - loss: 0.0950 - binary_accuracy: 0.9732 - false_negatives_1: 288.0000 - false_positives_1: 247.0000 - precision_1: 0.9757 - recall_1: 0.9718 - true_positives_1: 9920.0000 - true_negatives_1: 9544.0000 - auc_1: 0.9930
# Epoch 00009: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0950 - binary_accuracy: 0.9732 - false_negatives_1: 288.0000 - false_positives_1: 247.0000 - precision_1: 0.9757 - recall_1: 0.9718 - true_positives_1: 9920.0000 - true_negatives_1: 9544.0000 - auc_1: 0.9930 - val_loss: 0.6547 - val_binary_accuracy: 0.8236 - val_false_negatives_1: 453.0000 - val_false_positives_1: 429.0000 - val_precision_1: 0.8267 - val_recall_1: 0.8188 - val_true_positives_1: 2047.0000 - val_true_negatives_1: 2071.0000 - val_auc_1: 0.8977
# Epoch 10/20
# 79/79 [==============================] - ETA: 0s - loss: 0.0904 - binary_accuracy: 0.9732 - false_negatives_1: 263.0000 - false_positives_1: 273.0000 - precision_1: 0.9733 - recall_1: 0.9742 - true_positives_1: 9945.0000 - true_negatives_1: 9518.0000 - auc_1: 0.9935
# Epoch 00010: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 88ms/step - loss: 0.0904 - binary_accuracy: 0.9732 - false_negatives_1: 263.0000 - false_positives_1: 273.0000 - precision_1: 0.9733 - recall_1: 0.9742 - true_positives_1: 9945.0000 - true_negatives_1: 9518.0000 - auc_1: 0.9935 - val_loss: 0.7443 - val_binary_accuracy: 0.8150 - val_false_negatives_1: 643.0000 - val_false_positives_1: 282.0000 - val_precision_1: 0.8682 - val_recall_1: 0.7428 - val_true_positives_1: 1857.0000 - val_true_negatives_1: 2218.0000 - val_auc_1: 0.8934
# Epoch 11/20
# 79/79 [==============================] - ETA: 0s - loss: 0.0852 - binary_accuracy: 0.9757 - false_negatives_1: 243.0000 - false_positives_1: 243.0000 - precision_1: 0.9762 - recall_1: 0.9762 - true_positives_1: 9965.0000 - true_negatives_1: 9548.0000 - auc_1: 0.9942
# Epoch 00011: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 86ms/step - loss: 0.0852 - binary_accuracy: 0.9757 - false_negatives_1: 243.0000 - false_positives_1: 243.0000 - precision_1: 0.9762 - recall_1: 0.9762 - true_positives_1: 9965.0000 - true_negatives_1: 9548.0000 - auc_1: 0.9942 - val_loss: 0.7631 - val_binary_accuracy: 0.8170 - val_false_negatives_1: 450.0000 - val_false_positives_1: 465.0000 - val_precision_1: 0.8151 - val_recall_1: 0.8200 - val_true_positives_1: 2050.0000 - val_true_negatives_1: 2035.0000 - val_auc_1: 0.8888
# Epoch 12/20
# 79/79 [==============================] - ETA: 0s - loss: 0.0717 - binary_accuracy: 0.9795 - false_negatives_1: 191.0000 - false_positives_1: 218.0000 - precision_1: 0.9787 - recall_1: 0.9813 - true_positives_1: 10017.0000 - true_negatives_1: 9573.0000 - auc_1: 0.9954
# Epoch 00012: val_loss did not improve from 0.34901
# 79/79 [==============================] - 7s 85ms/step - loss: 0.0717 - binary_accuracy: 0.9795 - false_negatives_1: 191.0000 - false_positives_1: 218.0000 - precision_1: 0.9787 - recall_1: 0.9813 - true_positives_1: 10017.0000 - true_negatives_1: 9573.0000 - auc_1: 0.9954 - val_loss: 0.7668 - val_binary_accuracy: 0.8160 - val_false_negatives_1: 468.0000 - val_false_positives_1: 452.0000 - val_precision_1: 0.8180 - val_recall_1: 0.8128 - val_true_positives_1: 2032.0000 - val_true_negatives_1: 2048.0000 - val_auc_1: 0.8924
# Epoch 00012: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 454.0, Number of ones incorrectly classified: 324.0
# Sample ratio for positives: 0.41645244215938304, Sample ratio for negatives:0.583547557840617
# Starting training with 24998 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3394 - binary_accuracy: 0.8657 - false_negatives_2: 1597.0000 - false_positives_2: 1760.0000 - precision_2: 0.8587 - recall_2: 0.8701 - true_positives_2: 10693.0000 - true_negatives_2: 10948.0000 - auc_2: 0.9301
# Epoch 00001: val_loss improved from 0.34901 to 0.34572, saving model to AL_Model.h5
# 98/98 [==============================] - 19s 100ms/step - loss: 0.3394 - binary_accuracy: 0.8657 - false_negatives_2: 1597.0000 - false_positives_2: 1760.0000 - precision_2: 0.8587 - recall_2: 0.8701 - true_positives_2: 10693.0000 - true_negatives_2: 10948.0000 - auc_2: 0.9301 - val_loss: 0.3457 - val_binary_accuracy: 0.8500 - val_false_negatives_2: 261.0000 - val_false_positives_2: 489.0000 - val_precision_2: 0.8207 - val_recall_2: 0.8956 - val_true_positives_2: 2239.0000 - val_true_negatives_2: 2011.0000 - val_auc_2: 0.9296
# Epoch 2/20
# 98/98 [==============================] - ETA: 0s - loss: 0.3041 - binary_accuracy: 0.8804 - false_negatives_2: 1455.0000 - false_positives_2: 1534.0000 - precision_2: 0.8760 - recall_2: 0.8816 - true_positives_2: 10835.0000 - true_negatives_2: 11174.0000 - auc_2: 0.9440
# Epoch 00002: val_loss improved from 0.34572 to 0.34571, saving model to AL_Model.h5
# 98/98 [==============================] - 7s 74ms/step - loss: 0.3041 - binary_accuracy: 0.8804 - false_negatives_2: 1455.0000 - false_positives_2: 1534.0000 - precision_2: 0.8760 - recall_2: 0.8816 - true_positives_2: 10835.0000 - true_negatives_2: 11174.0000 - auc_2: 0.9440 - val_loss: 0.3457 - val_binary_accuracy: 0.8486 - val_false_negatives_2: 413.0000 - val_false_positives_2: 344.0000 - val_precision_2: 0.8585 - val_recall_2: 0.8348 - val_true_positives_2: 2087.0000 - val_true_negatives_2: 2156.0000 - val_auc_2: 0.9305
# Epoch 3/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2845 - binary_accuracy: 0.8889 - false_negatives_2: 1365.0000 - false_positives_2: 1413.0000 - precision_2: 0.8855 - recall_2: 0.8889 - true_positives_2: 10925.0000 - true_negatives_2: 11295.0000 - auc_2: 0.9511
# Epoch 00003: val_loss did not improve from 0.34571
# 98/98 [==============================] - 9s 87ms/step - loss: 0.2845 - binary_accuracy: 0.8889 - false_negatives_2: 1365.0000 - false_positives_2: 1413.0000 - precision_2: 0.8855 - recall_2: 0.8889 - true_positives_2: 10925.0000 - true_negatives_2: 11295.0000 - auc_2: 0.9511 - val_loss: 0.3625 - val_binary_accuracy: 0.8334 - val_false_negatives_2: 572.0000 - val_false_positives_2: 261.0000 - val_precision_2: 0.8808 - val_recall_2: 0.7712 - val_true_positives_2: 1928.0000 - val_true_negatives_2: 2239.0000 - val_auc_2: 0.9272
# Epoch 4/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2672 - binary_accuracy: 0.8977 - false_negatives_2: 1277.0000 - false_positives_2: 1281.0000 - precision_2: 0.8958 - recall_2: 0.8961 - true_positives_2: 11013.0000 - true_negatives_2: 11427.0000 - auc_2: 0.9571
# Epoch 00004: val_loss did not improve from 0.34571
# 98/98 [==============================] - 9s 92ms/step - loss: 0.2672 - binary_accuracy: 0.8977 - false_negatives_2: 1277.0000 - false_positives_2: 1281.0000 - precision_2: 0.8958 - recall_2: 0.8961 - true_positives_2: 11013.0000 - true_negatives_2: 11427.0000 - auc_2: 0.9571 - val_loss: 0.3506 - val_binary_accuracy: 0.8464 - val_false_negatives_2: 298.0000 - val_false_positives_2: 470.0000 - val_precision_2: 0.8241 - val_recall_2: 0.8808 - val_true_positives_2: 2202.0000 - val_true_negatives_2: 2030.0000 - val_auc_2: 0.9275
# Epoch 5/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2481 - binary_accuracy: 0.9059 - false_negatives_2: 1150.0000 - false_positives_2: 1202.0000 - precision_2: 0.9026 - recall_2: 0.9064 - true_positives_2: 11140.0000 - true_negatives_2: 11506.0000 - auc_2: 0.9628
# Epoch 00005: val_loss did not improve from 0.34571
# 98/98 [==============================] - 9s 87ms/step - loss: 0.2481 - binary_accuracy: 0.9059 - false_negatives_2: 1150.0000 - false_positives_2: 1202.0000 - precision_2: 0.9026 - recall_2: 0.9064 - true_positives_2: 11140.0000 - true_negatives_2: 11506.0000 - auc_2: 0.9628 - val_loss: 0.3679 - val_binary_accuracy: 0.8488 - val_false_negatives_2: 396.0000 - val_false_positives_2: 360.0000 - val_precision_2: 0.8539 - val_recall_2: 0.8416 - val_true_positives_2: 2104.0000 - val_true_negatives_2: 2140.0000 - val_auc_2: 0.9270
# Epoch 6/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2339 - binary_accuracy: 0.9154 - false_negatives_2: 1079.0000 - false_positives_2: 1037.0000 - precision_2: 0.9153 - recall_2: 0.9122 - true_positives_2: 11211.0000 - true_negatives_2: 11671.0000 - auc_2: 0.9670
# Epoch 00006: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.2339 - binary_accuracy: 0.9154 - false_negatives_2: 1079.0000 - false_positives_2: 1037.0000 - precision_2: 0.9153 - recall_2: 0.9122 - true_positives_2: 11211.0000 - true_negatives_2: 11671.0000 - auc_2: 0.9670 - val_loss: 0.3964 - val_binary_accuracy: 0.8440 - val_false_negatives_2: 265.0000 - val_false_positives_2: 515.0000 - val_precision_2: 0.8127 - val_recall_2: 0.8940 - val_true_positives_2: 2235.0000 - val_true_negatives_2: 1985.0000 - val_auc_2: 0.9255
# Epoch 7/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2181 - binary_accuracy: 0.9220 - false_negatives_2: 1008.0000 - false_positives_2: 943.0000 - precision_2: 0.9229 - recall_2: 0.9180 - true_positives_2: 11282.0000 - true_negatives_2: 11765.0000 - auc_2: 0.9710
# Epoch 00007: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.2181 - binary_accuracy: 0.9220 - false_negatives_2: 1008.0000 - false_positives_2: 943.0000 - precision_2: 0.9229 - recall_2: 0.9180 - true_positives_2: 11282.0000 - true_negatives_2: 11765.0000 - auc_2: 0.9710 - val_loss: 0.4146 - val_binary_accuracy: 0.8402 - val_false_negatives_2: 223.0000 - val_false_positives_2: 576.0000 - val_precision_2: 0.7981 - val_recall_2: 0.9108 - val_true_positives_2: 2277.0000 - val_true_negatives_2: 1924.0000 - val_auc_2: 0.9237
# Epoch 8/20
# 98/98 [==============================] - ETA: 0s - loss: 0.2033 - binary_accuracy: 0.9285 - false_negatives_2: 896.0000 - false_positives_2: 892.0000 - precision_2: 0.9274 - recall_2: 0.9271 - true_positives_2: 11394.0000 - true_negatives_2: 11816.0000 - auc_2: 0.9747
# Epoch 00008: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 86ms/step - loss: 0.2033 - binary_accuracy: 0.9285 - false_negatives_2: 896.0000 - false_positives_2: 892.0000 - precision_2: 0.9274 - recall_2: 0.9271 - true_positives_2: 11394.0000 - true_negatives_2: 11816.0000 - auc_2: 0.9747 - val_loss: 0.4101 - val_binary_accuracy: 0.8438 - val_false_negatives_2: 309.0000 - val_false_positives_2: 472.0000 - val_precision_2: 0.8228 - val_recall_2: 0.8764 - val_true_positives_2: 2191.0000 - val_true_negatives_2: 2028.0000 - val_auc_2: 0.9224
# Epoch 9/20
# 98/98 [==============================] - ETA: 0s - loss: 0.1892 - binary_accuracy: 0.9340 - false_negatives_2: 856.0000 - false_positives_2: 795.0000 - precision_2: 0.9350 - recall_2: 0.9303 - true_positives_2: 11434.0000 - true_negatives_2: 11913.0000 - auc_2: 0.9779
# Epoch 00009: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.1892 - binary_accuracy: 0.9340 - false_negatives_2: 856.0000 - false_positives_2: 795.0000 - precision_2: 0.9350 - recall_2: 0.9303 - true_positives_2: 11434.0000 - true_negatives_2: 11913.0000 - auc_2: 0.9779 - val_loss: 0.4985 - val_binary_accuracy: 0.8144 - val_false_negatives_2: 715.0000 - val_false_positives_2: 213.0000 - val_precision_2: 0.8934 - val_recall_2: 0.7140 - val_true_positives_2: 1785.0000 - val_true_negatives_2: 2287.0000 - val_auc_2: 0.9164
# Epoch 10/20
# 98/98 [==============================] - ETA: 0s - loss: 0.1769 - binary_accuracy: 0.9386 - false_negatives_2: 814.0000 - false_positives_2: 722.0000 - precision_2: 0.9408 - recall_2: 0.9338 - true_positives_2: 11476.0000 - true_negatives_2: 11986.0000 - auc_2: 0.9804
# Epoch 00010: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.1769 - binary_accuracy: 0.9386 - false_negatives_2: 814.0000 - false_positives_2: 722.0000 - precision_2: 0.9408 - recall_2: 0.9338 - true_positives_2: 11476.0000 - true_negatives_2: 11986.0000 - auc_2: 0.9804 - val_loss: 0.4601 - val_binary_accuracy: 0.8154 - val_false_negatives_2: 675.0000 - val_false_positives_2: 248.0000 - val_precision_2: 0.8804 - val_recall_2: 0.7300 - val_true_positives_2: 1825.0000 - val_true_negatives_2: 2252.0000 - val_auc_2: 0.9147
# Epoch 11/20
# 98/98 [==============================] - ETA: 0s - loss: 0.1624 - binary_accuracy: 0.9442 - false_negatives_2: 727.0000 - false_positives_2: 668.0000 - precision_2: 0.9454 - recall_2: 0.9408 - true_positives_2: 11563.0000 - true_negatives_2: 12040.0000 - auc_2: 0.9832
# Epoch 00011: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.1624 - binary_accuracy: 0.9442 - false_negatives_2: 727.0000 - false_positives_2: 668.0000 - precision_2: 0.9454 - recall_2: 0.9408 - true_positives_2: 11563.0000 - true_negatives_2: 12040.0000 - auc_2: 0.9832 - val_loss: 0.4993 - val_binary_accuracy: 0.8392 - val_false_negatives_2: 418.0000 - val_false_positives_2: 386.0000 - val_precision_2: 0.8436 - val_recall_2: 0.8328 - val_true_positives_2: 2082.0000 - val_true_negatives_2: 2114.0000 - val_auc_2: 0.9159
# Epoch 12/20
# 98/98 [==============================] - ETA: 0s - loss: 0.1502 - binary_accuracy: 0.9499 - false_negatives_2: 648.0000 - false_positives_2: 604.0000 - precision_2: 0.9507 - recall_2: 0.9473 - true_positives_2: 11642.0000 - true_negatives_2: 12104.0000 - auc_2: 0.9854
# Epoch 00012: val_loss did not improve from 0.34571
# 98/98 [==============================] - 8s 85ms/step - loss: 0.1502 - binary_accuracy: 0.9499 - false_negatives_2: 648.0000 - false_positives_2: 604.0000 - precision_2: 0.9507 - recall_2: 0.9473 - true_positives_2: 11642.0000 - true_negatives_2: 12104.0000 - auc_2: 0.9854 - val_loss: 0.5357 - val_binary_accuracy: 0.8348 - val_false_negatives_2: 424.0000 - val_false_positives_2: 402.0000 - val_precision_2: 0.8378 - val_recall_2: 0.8304 - val_true_positives_2: 2076.0000 - val_true_negatives_2: 2098.0000 - val_auc_2: 0.9125
# Epoch 00012: early stopping
# ----------------------------------------------------------------------------------------------------
# Number of zeros incorrectly classified: 425.0, Number of ones incorrectly classified: 329.0
# Sample ratio for positives: 0.4363395225464191, Sample ratio for negatives:0.5636604774535809
# Starting training with 29997 samples
# ----------------------------------------------------------------------------------------------------
# Epoch 1/20
# 118/118 [==============================] - ETA: 0s - loss: 0.3113 - binary_accuracy: 0.8793 - false_negatives_3: 1759.0000 - false_positives_3: 1861.0000 - precision_3: 0.8723 - recall_3: 0.8784 - true_positives_3: 12712.0000 - true_negatives_3: 13665.0000 - auc_3: 0.9415
# Epoch 00001: val_loss did not improve from 0.34571
# 118/118 [==============================] - 25s 119ms/step - loss: 0.3113 - binary_accuracy: 0.8793 - false_negatives_3: 1759.0000 - false_positives_3: 1861.0000 - precision_3: 0.8723 - recall_3: 0.8784 - true_positives_3: 12712.0000 - true_negatives_3: 13665.0000 - auc_3: 0.9415 - val_loss: 0.3623 - val_binary_accuracy: 0.8412 - val_false_negatives_3: 574.0000 - val_false_positives_3: 220.0000 - val_precision_3: 0.8975 - val_recall_3: 0.7704 - val_true_positives_3: 1926.0000 - val_true_negatives_3: 2280.0000 - val_auc_3: 0.9306
# Epoch 2/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2826 - binary_accuracy: 0.8916 - false_negatives_3: 1626.0000 - false_positives_3: 1625.0000 - precision_3: 0.8877 - recall_3: 0.8876 - true_positives_3: 12845.0000 - true_negatives_3: 13901.0000 - auc_3: 0.9518
# Epoch 00002: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 82ms/step - loss: 0.2826 - binary_accuracy: 0.8916 - false_negatives_3: 1626.0000 - false_positives_3: 1625.0000 - precision_3: 0.8877 - recall_3: 0.8876 - true_positives_3: 12845.0000 - true_negatives_3: 13901.0000 - auc_3: 0.9518 - val_loss: 0.3669 - val_binary_accuracy: 0.8474 - val_false_negatives_3: 204.0000 - val_false_positives_3: 559.0000 - val_precision_3: 0.8042 - val_recall_3: 0.9184 - val_true_positives_3: 2296.0000 - val_true_negatives_3: 1941.0000 - val_auc_3: 0.9311
# Epoch 3/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2645 - binary_accuracy: 0.9008 - false_negatives_3: 1464.0000 - false_positives_3: 1512.0000 - precision_3: 0.8959 - recall_3: 0.8988 - true_positives_3: 13007.0000 - true_negatives_3: 14014.0000 - auc_3: 0.9577
# Epoch 00003: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 84ms/step - loss: 0.2645 - binary_accuracy: 0.9008 - false_negatives_3: 1464.0000 - false_positives_3: 1512.0000 - precision_3: 0.8959 - recall_3: 0.8988 - true_positives_3: 13007.0000 - true_negatives_3: 14014.0000 - auc_3: 0.9577 - val_loss: 0.3545 - val_binary_accuracy: 0.8522 - val_false_negatives_3: 254.0000 - val_false_positives_3: 485.0000 - val_precision_3: 0.8224 - val_recall_3: 0.8984 - val_true_positives_3: 2246.0000 - val_true_negatives_3: 2015.0000 - val_auc_3: 0.9297
# Epoch 4/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2485 - binary_accuracy: 0.9083 - false_negatives_3: 1355.0000 - false_positives_3: 1397.0000 - precision_3: 0.9037 - recall_3: 0.9064 - true_positives_3: 13116.0000 - true_negatives_3: 14129.0000 - auc_3: 0.9628
# Epoch 00004: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 83ms/step - loss: 0.2485 - binary_accuracy: 0.9083 - false_negatives_3: 1355.0000 - false_positives_3: 1397.0000 - precision_3: 0.9037 - recall_3: 0.9064 - true_positives_3: 13116.0000 - true_negatives_3: 14129.0000 - auc_3: 0.9628 - val_loss: 0.3982 - val_binary_accuracy: 0.8484 - val_false_negatives_3: 483.0000 - val_false_positives_3: 275.0000 - val_precision_3: 0.8800 - val_recall_3: 0.8068 - val_true_positives_3: 2017.0000 - val_true_negatives_3: 2225.0000 - val_auc_3: 0.9283
# Epoch 5/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2355 - binary_accuracy: 0.9131 - false_negatives_3: 1340.0000 - false_positives_3: 1266.0000 - precision_3: 0.9121 - recall_3: 0.9074 - true_positives_3: 13131.0000 - true_negatives_3: 14260.0000 - auc_3: 0.9663
# Epoch 00005: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 83ms/step - loss: 0.2355 - binary_accuracy: 0.9131 - false_negatives_3: 1340.0000 - false_positives_3: 1266.0000 - precision_3: 0.9121 - recall_3: 0.9074 - true_positives_3: 13131.0000 - true_negatives_3: 14260.0000 - auc_3: 0.9663 - val_loss: 0.3781 - val_binary_accuracy: 0.8472 - val_false_negatives_3: 257.0000 - val_false_positives_3: 507.0000 - val_precision_3: 0.8156 - val_recall_3: 0.8972 - val_true_positives_3: 2243.0000 - val_true_negatives_3: 1993.0000 - val_auc_3: 0.9293
# Epoch 6/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2246 - binary_accuracy: 0.9200 - false_negatives_3: 1202.0000 - false_positives_3: 1199.0000 - precision_3: 0.9171 - recall_3: 0.9169 - true_positives_3: 13269.0000 - true_negatives_3: 14327.0000 - auc_3: 0.9694
# Epoch 00006: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 84ms/step - loss: 0.2246 - binary_accuracy: 0.9200 - false_negatives_3: 1202.0000 - false_positives_3: 1199.0000 - precision_3: 0.9171 - recall_3: 0.9169 - true_positives_3: 13269.0000 - true_negatives_3: 14327.0000 - auc_3: 0.9694 - val_loss: 0.4755 - val_binary_accuracy: 0.8076 - val_false_negatives_3: 817.0000 - val_false_positives_3: 145.0000 - val_precision_3: 0.9207 - val_recall_3: 0.6732 - val_true_positives_3: 1683.0000 - val_true_negatives_3: 2355.0000 - val_auc_3: 0.9246
# Epoch 7/20
# 118/118 [==============================] - ETA: 0s - loss: 0.2054 - binary_accuracy: 0.9265 - false_negatives_3: 1125.0000 - false_positives_3: 1079.0000 - precision_3: 0.9252 - recall_3: 0.9223 - true_positives_3: 13346.0000 - true_negatives_3: 14447.0000 - auc_3: 0.9740
# Epoch 00007: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 84ms/step - loss: 0.2054 - binary_accuracy: 0.9265 - false_negatives_3: 1125.0000 - false_positives_3: 1079.0000 - precision_3: 0.9252 - recall_3: 0.9223 - true_positives_3: 13346.0000 - true_negatives_3: 14447.0000 - auc_3: 0.9740 - val_loss: 0.4470 - val_binary_accuracy: 0.8302 - val_false_negatives_3: 554.0000 - val_false_positives_3: 295.0000 - val_precision_3: 0.8684 - val_recall_3: 0.7784 - val_true_positives_3: 1946.0000 - val_true_negatives_3: 2205.0000 - val_auc_3: 0.9213
# Epoch 8/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1931 - binary_accuracy: 0.9317 - false_negatives_3: 1025.0000 - false_positives_3: 1023.0000 - precision_3: 0.9293 - recall_3: 0.9292 - true_positives_3: 13446.0000 - true_negatives_3: 14503.0000 - auc_3: 0.9768
# Epoch 00008: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 83ms/step - loss: 0.1931 - binary_accuracy: 0.9317 - false_negatives_3: 1025.0000 - false_positives_3: 1023.0000 - precision_3: 0.9293 - recall_3: 0.9292 - true_positives_3: 13446.0000 - true_negatives_3: 14503.0000 - auc_3: 0.9768 - val_loss: 0.4254 - val_binary_accuracy: 0.8430 - val_false_negatives_3: 317.0000 - val_false_positives_3: 468.0000 - val_precision_3: 0.8235 - val_recall_3: 0.8732 - val_true_positives_3: 2183.0000 - val_true_negatives_3: 2032.0000 - val_auc_3: 0.9242
# Epoch 9/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1784 - binary_accuracy: 0.9379 - false_negatives_3: 921.0000 - false_positives_3: 943.0000 - precision_3: 0.9349 - recall_3: 0.9364 - true_positives_3: 13550.0000 - true_negatives_3: 14583.0000 - auc_3: 0.9800
# Epoch 00009: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 82ms/step - loss: 0.1784 - binary_accuracy: 0.9379 - false_negatives_3: 921.0000 - false_positives_3: 943.0000 - precision_3: 0.9349 - recall_3: 0.9364 - true_positives_3: 13550.0000 - true_negatives_3: 14583.0000 - auc_3: 0.9800 - val_loss: 0.4851 - val_binary_accuracy: 0.8326 - val_false_negatives_3: 216.0000 - val_false_positives_3: 621.0000 - val_precision_3: 0.7862 - val_recall_3: 0.9136 - val_true_positives_3: 2284.0000 - val_true_negatives_3: 1879.0000 - val_auc_3: 0.9201
# Epoch 10/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1645 - binary_accuracy: 0.9441 - false_negatives_3: 809.0000 - false_positives_3: 869.0000 - precision_3: 0.9402 - recall_3: 0.9441 - true_positives_3: 13662.0000 - true_negatives_3: 14657.0000 - auc_3: 0.9826
# Epoch 00010: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 82ms/step - loss: 0.1645 - binary_accuracy: 0.9441 - false_negatives_3: 809.0000 - false_positives_3: 869.0000 - precision_3: 0.9402 - recall_3: 0.9441 - true_positives_3: 13662.0000 - true_negatives_3: 14657.0000 - auc_3: 0.9826 - val_loss: 0.4612 - val_binary_accuracy: 0.8420 - val_false_negatives_3: 408.0000 - val_false_positives_3: 382.0000 - val_precision_3: 0.8456 - val_recall_3: 0.8368 - val_true_positives_3: 2092.0000 - val_true_negatives_3: 2118.0000 - val_auc_3: 0.9210
# Epoch 11/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1484 - binary_accuracy: 0.9503 - false_negatives_3: 728.0000 - false_positives_3: 763.0000 - precision_3: 0.9474 - recall_3: 0.9497 - true_positives_3: 13743.0000 - true_negatives_3: 14763.0000 - auc_3: 0.9858
# Epoch 00011: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 83ms/step - loss: 0.1484 - binary_accuracy: 0.9503 - false_negatives_3: 728.0000 - false_positives_3: 763.0000 - precision_3: 0.9474 - recall_3: 0.9497 - true_positives_3: 13743.0000 - true_negatives_3: 14763.0000 - auc_3: 0.9858 - val_loss: 0.5108 - val_binary_accuracy: 0.8280 - val_false_negatives_3: 567.0000 - val_false_positives_3: 293.0000 - val_precision_3: 0.8684 - val_recall_3: 0.7732 - val_true_positives_3: 1933.0000 - val_true_negatives_3: 2207.0000 - val_auc_3: 0.9156
# Epoch 12/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1365 - binary_accuracy: 0.9567 - false_negatives_3: 630.0000 - false_positives_3: 669.0000 - precision_3: 0.9539 - recall_3: 0.9565 - true_positives_3: 13841.0000 - true_negatives_3: 14857.0000 - auc_3: 0.9876
# Epoch 00012: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 82ms/step - loss: 0.1365 - binary_accuracy: 0.9567 - false_negatives_3: 630.0000 - false_positives_3: 669.0000 - precision_3: 0.9539 - recall_3: 0.9565 - true_positives_3: 13841.0000 - true_negatives_3: 14857.0000 - auc_3: 0.9876 - val_loss: 0.5394 - val_binary_accuracy: 0.8436 - val_false_negatives_3: 351.0000 - val_false_positives_3: 431.0000 - val_precision_3: 0.8329 - val_recall_3: 0.8596 - val_true_positives_3: 2149.0000 - val_true_negatives_3: 2069.0000 - val_auc_3: 0.9148
# Epoch 13/20
# 118/118 [==============================] - ETA: 0s - loss: 0.1214 - binary_accuracy: 0.9614 - false_negatives_3: 560.0000 - false_positives_3: 597.0000 - precision_3: 0.9589 - recall_3: 0.9613 - true_positives_3: 13911.0000 - true_negatives_3: 14929.0000 - auc_3: 0.9899
# Epoch 00013: val_loss did not improve from 0.34571
# 118/118 [==============================] - 10s 82ms/step - loss: 0.1214 - binary_accuracy: 0.9614 - false_negatives_3: 560.0000 - false_positives_3: 597.0000 - precision_3: 0.9589 - recall_3: 0.9613 - true_positives_3: 13911.0000 - true_negatives_3: 14929.0000 - auc_3: 0.9899 - val_loss: 0.5618 - val_binary_accuracy: 0.8376 - val_false_negatives_3: 390.0000 - val_false_positives_3: 422.0000 - val_precision_3: 0.8333 - val_recall_3: 0.8440 - val_true_positives_3: 2110.0000 - val_true_negatives_3: 2078.0000 - val_auc_3: 0.9102
# Epoch 00013: early stopping
# ----------------------------------------------------------------------------------------------------
# Test set evaluation:  {'loss': 0.3510935306549072, 'binary_accuracy': 0.8492000102996826, 'false_negatives_2': 425.0, 'false_positives_2': 329.0, 'precision_2': 0.8631447553634644, 'recall_2': 0.8299999833106995, 'true_positives_2': 2075.0, 'true_negatives_2': 2171.0, 'auc_2': 0.9292331337928772}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Conclusion
#
#
# The following are some  observations from this excerise:
#
# 1. We only require 30,000 samples to reach the same (if not better) scores as the model
# trained on the full datatset. This means that in a real life setting, we save the effort
# required for annotating 10,000 images!
# 2. The number of false negatives and false positives are well balanced at the end of the
# training as compared to the skewed ratio obtained from the full training. This makes the
# model slightly more useful in real life scenarios where both the labels hold equal
# importance.
